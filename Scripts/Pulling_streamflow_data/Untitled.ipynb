# %%
import requests

import os 
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import matplotlib.pyplot as plt


# %matplotlib notebook


import json

# %%
jsondada = os.path.join("full.json")
fucka = pd.read_json(jsondada)['location']
dicka = pd.read_json(jsondada)

fucka[0]['latitude']
fucka[0]['latitude']

Lat = []
Lon = []
ID = []
name = []

for indx, values in fucka.items():
    Lat.append(values['latitude'])
    Lon.append(values['longitude'])
    
for indx, values in dicka['name'].items():
    name.append(values['en'])
    
    
data = pd.DataFrame(columns=["Lat", 'Lon'])
data['Lat'] = Lat
data['Lon'] = Lon
data["ID"] = dicka['id']
data["name"] = name

# %%
data.to_csv("SillyStations2.csv")

# %%
name = []
# Out:
# Holden Agdm
# Athabasca 1
# Jan Mayen
# Grahuken
# Hornsund
# New Alesund II
# Barentsburg
# Edgeoya
# New Alesund
# Svalbard Lufthavn
# Phippsoya
# Kvitoya
# Vollen
# Hekkingen Lighthouse
# Senja-Grasmyrskogen
# Barentsburg
# Svarttangen
# Sorkappoya
# Lanes
# Tromso Airport
# Tromso
# Tromso-holt / Åsgård
# Bjornoya
# Torsvag Lighthouse
# Fugloykalven Lighthouse
# Skibotn / Skibotin
# Nodreisa-Oyeng
# Hasvik Ap
# Nordstraum I Kvaenangen
# Sorkjosen
# Kautokeino
# Alta Airport
# Suolovuopmi
# Fruholmen Lighthouse
# Cuovddatmohkki
# Suolovuopmi Lulit / Masi
# Banak
# Hopen
# Karasjok
# Helnes Fyr
# Honningsvag Airport
# Mehamn
# Rustefjelbma
# Sletnes Lighthouse
# Berlevag
# Batsfjord Ap / Straumen
# Makkaur Fyr
# Svartnes
# Vardo
# Vardo Ap / Svartnes
# Svartnes
# Sklinna Lighthouse
# Leka
# Skomvaer Fyr / Nes
# Rost II
# Vega-Vallsjo
# Ytterholmen Lighthouse
# Reipa
# Sandnessjoen Airport
# Tjotta
# Kjobli I Snasa / Åsan
# Majavatn
# Laksfors / Fallmoen
# Majavatn Iii
# Seljelia
# ...

# %%
name
# Out:
# ['Holden Agdm',
#  'Athabasca 1',
#  'Jan Mayen',
#  'Grahuken',
#  'Hornsund',
#  'New Alesund II',
#  'Barentsburg',
#  'Edgeoya',
#  'New Alesund',
#  'Svalbard Lufthavn',
#  'Phippsoya',
#  'Kvitoya',
#  'Vollen',
#  'Hekkingen Lighthouse',
#  'Senja-Grasmyrskogen',
#  'Barentsburg',
#  'Svarttangen',
#  'Sorkappoya',
#  'Lanes',
#  'Tromso Airport',
#  'Tromso',
#  'Tromso-holt / Åsgård',
#  'Bjornoya',
#  'Torsvag Lighthouse',
#  'Fugloykalven Lighthouse',
#  'Skibotn / Skibotin',
#  'Nodreisa-Oyeng',
#  'Hasvik Ap',
#  'Nordstraum I Kvaenangen',
#  'Sorkjosen',
#  'Kautokeino',
#  'Alta Airport',
#  'Suolovuopmi',
#  'Fruholmen Lighthouse',
#  'Cuovddatmohkki',
#  'Suolovuopmi Lulit / Masi',
#  'Banak',
#  'Hopen',
#  'Karasjok',
#  'Helnes Fyr',
#  'Honningsvag Airport',
#  'Mehamn',
#  'Rustefjelbma',
#  'Sletnes Lighthouse',
#  'Berlevag',
#  'Batsfjord Ap / Straumen',
#  'Makkaur Fyr',
#  'Svartnes',
#  'Vardo',
#  'Vardo Ap / Svartnes',
#  'Svartnes',
# ...

# %%
data
# Out:
#            Lat       Lon
# 0      53.1900 -112.2500
# 1      54.7200 -113.2900
# 2      70.9333   -8.6667
# 3      79.7833   14.4667
# 4      77.0000   15.5000
# ...        ...       ...
# 21754  44.2300  -76.6000
# 21755  59.9190   10.6350
# 21756  42.6046  -82.8353
# 21757  41.8000  123.4000
# 21758  43.8300  -80.1200
#
# [21759 rows x 2 columns]
